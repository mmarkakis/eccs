# %%
# Let's first generate some data
# Define a dataset of 1000 samples of 3 variables
# z is a random integer between 0 and 100, x is equal to z plus gaussian noise, y is equal to 2z plus gaussian noise
import numpy as np
import pandas as pd

np.random.seed(0)
z = np.random.randint(0, 100, 1000)
x = z + np.random.normal(0, 1, 1000)
y = 2 * z + np.random.normal(0, 1, 1000)

# Create a pandas DataFrame with the 3 variables
df = pd.DataFrame({'x': x, 'y': y, 'z': z})
df.head()
# Out:
# /tmp/ipykernel_610180/4258775915.py:5: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
#            x           y   z
# 0  44.222456   88.539313  44
# 1  47.310249   93.584211  47
# 2  64.668471  127.281524  64
# 3  66.272320  132.723982  67
# 4  65.530862  133.965265  67

# %%
import sys
sys.path.append('..')
from eccs.optimizer import Optimizer

# %%
o = Optimizer(df, 0, 1)

# %%
x = o.optimize(2, set(), set(), 0.1, 0.1)
# Out:
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (linux64 - "Arch Linux")
#
# CPU model: Intel(R) Xeon(R) Gold 6230 CPU @ 2.10GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 40 physical cores, 80 logical processors, using up to 32 threads
#
# Optimize a model with 2 rows, 7 columns and 2 nonzeros
# Model fingerprint: 0xd07e4a99
# Model has 1 quadratic objective term
# Model has 1 quadratic constraint
# Variable types: 4 continuous, 3 integer (3 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   QMatrix range    [3e+03, 1e+04]
#   QLMatrix range   [1e+00, 3e+04]
#   Objective range  [1e-01, 1e+00]
#   QObjective range [2e-01, 2e-01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#   QRHS range       [1e+04, 1e+04]
# Presolve removed 2 rows and 3 columns
# Presolve time: 0.00s
# Presolved: 1 rows, 6 columns, 2 nonzeros
# Presolved model has 1 quadratic constraint(s)
# Presolved model has 1 bilinear constraint(s)
# ...

# %%
# Out:
# None
